# %% [markdown]
# ## Data Science Code

# %% [markdown]
# ### Pandas

# %%
import pandas as pd

data = pd.read_csv('.csv') #read csv
data = pd.read_excel('.xlsx') #read excel
data.head() #5 teratas
data.tail() #5 terbawah
data.info() #informasi data
data.describe #desc stat
data.isnull() #data NaN
data.isnull().sum() #jumlah data NaN
data.dropna() #drop NaN
data.iloc() #tembak data
data.loc() #tembak based on loc
data.values() #ubah ke array
data = data.drop(columns='') #drop column
data.fillna() 
data.append() #add
data.gropuby() #groupby

# %% [markdown]
# ### Numpy

# %%
import numpy as np

np.array
# Out:
# <function numpy.array>

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x = data['column1']
y = data['column2']
plt.title('Judul')
plt.xlabel('labelx')
plt.ylabel('labely')
plt.show()

# %%
X = np.linspace(0, 4*np.pi, 1000)
Y = np.sin(X)

# %%
fig, ax = plt.subplots()
ax.plot(X, Y)
fig.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17456\876543767.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
X = np.random.uniform(0, 1, 100)
Y = np.random.uniform(0, 1, 100)
plt.scatter(X, Y)
plt.show()

# %%
X = np.arange(10)
Y = np.random.uniform(1, 10, 10)
plt.bar(X, Y, color='red')
plt.show()

# %%
 Z = np.random.uniform(0, 1, (8,8))
 plt.imshow(Z)

# %%
Z = np.random.uniform(0, 1, (8,8))
plt.contourf(Z)

# %%
Z = np.random.uniform(0, 1, 4)
plt.pie(Z)
# Out:
# ([<matplotlib.patches.Wedge at 0x269e575ccd0>,
#   <matplotlib.patches.Wedge at 0x269e575d150>,
#   <matplotlib.patches.Wedge at 0x269e575d5d0>,
#   <matplotlib.patches.Wedge at 0x269e575da50>],
#  [Text(0.13152075979255082, 1.0921091015752915, ''),
#   Text(-1.0815352329028425, 0.20070261580207266, ''),
#   Text(-0.08951897557061385, -1.0963513820909736, ''),
#   Text(1.0998250140918784, -0.019619846528441398, '')])

# %%
Z = np.random.normal(0, 1, 100)
plt.hist(Z)
# Out:
# (array([ 1.,  3.,  3., 13., 16., 22., 15., 17.,  7.,  3.]),
#  array([-3.07418869, -2.53182141, -1.98945413, -1.44708685, -0.90471957,
#         -0.36235229,  0.18001499,  0.72238227,  1.26474956,  1.80711684,
#          2.34948412]),
#  <BarContainer object of 10 artists>)

# %%
X = np.arange(5)
Y = np.random.uniform(0, 1, 5)
plt.errorbar(X, Y, Y/4)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
Z = np.random.normal(0, 1, (100,3))
plt.boxplot(Z)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x269e69fe1d0>,
#   <matplotlib.lines.Line2D at 0x269e69fe470>,
#   <matplotlib.lines.Line2D at 0x269e69ff430>,
#   <matplotlib.lines.Line2D at 0x269e69ff6d0>,
#   <matplotlib.lines.Line2D at 0x269e6a3c0a0>,
#   <matplotlib.lines.Line2D at 0x269e6a3c340>],
#  'caps': [<matplotlib.lines.Line2D at 0x269e69fe710>,
#   <matplotlib.lines.Line2D at 0x269e69fe9b0>,
#   <matplotlib.lines.Line2D at 0x269e68692a0>,
#   <matplotlib.lines.Line2D at 0x269e680ed70>,
#   <matplotlib.lines.Line2D at 0x269e6a3c5e0>,
#   <matplotlib.lines.Line2D at 0x269e6a3c880>],
#  'boxes': [<matplotlib.lines.Line2D at 0x269e69fdf30>,
#   <matplotlib.lines.Line2D at 0x269e69ff190>,
#   <matplotlib.lines.Line2D at 0x269e69ffdc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x269e69fec50>,
#   <matplotlib.lines.Line2D at 0x269e69ff880>,
#   <matplotlib.lines.Line2D at 0x269e6a3cb20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x269e69feef0>,
#   <matplotlib.lines.Line2D at 0x269e69ffb20>,
#   <matplotlib.lines.Line2D at 0x269e6a3cdc0>],
#  'means': []}

# %%
X = np.linspace(0, 10, 100)
Y = np.sin(X)

plt.plot(X, Y, color='black')

# %%
X = np.linspace(0, 10, 100)
Y = np.sin(X)

plt.plot(X, Y, linestyle='--')

# %%
X = np.linspace(0, 10, 100)
Y = np.sin(X)
plt.plot(X, Y, linewidth=5)

# %%
X = np.linspace(0, 10, 100)
Y = np.sin(X)

plt.plot(X, Y, marker='o')
