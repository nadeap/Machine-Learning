# %% [markdown]
# ### Declare Dataset

# %%
x = data.drop(columns='nama_columns')
y = data['nama_columns']

# %%
x = data[:,:-1]
y = data[:,-1]

# %%
x = data['column1','column2','column3']
y = data['columnx']

# %% [markdown]
# ### Split Dataset

# %%
from sklearn.model_selection import train_test_split

x_train, x_text, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %% [markdown]
# ### Feature Scaling (Min-Max Scaling)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Tujuan = Normalisasi data (12000 vs 0.2) = maka nilainya akan berada di antara min dan max

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler_data = scaler.fit_transform(data['column1'])

# %% [markdown]
# ### Feature Scaling (Standardization/Variance Scaling)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.preprocessing import StandardScaler

scale= StandardScaler()
scaled_data = scale.fit_transform(data['columns1'])

# %% [markdown]
# ### Feature Scaling (L Normalization)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn import preprocessing

normalized_data_l2 = preprocessing.normalize(input_data, norm='l2')

# %% [markdown]
# ### Result the different between 3 Feature Scaling

# %% [markdown]
# ![image.png](attachment:image.png)
